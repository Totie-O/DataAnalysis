# %% [markdown]
# ## 时间序列

# %%
from datetime import datetime

t = datetime.now()
print(t, type(t))
print(t.year,t.month,t.day)
# Out:
# 2021-06-30 20:43:51.143906 <class 'datetime.datetime'>
# 2021 6 30

# %%
t.weekday() + 1 #Python中几周从0开始数的，周日返回的是6，所以在后面加1
# Out:
# 3

# %%
t.isocalendar() #返回当前所在周的周数，以及周几
# Out:
# (2021, 26, 3)

# %%
weeknum = t.isocalendar()[1]
weekday = t.isocalendar()[2]
print(weeknum,weekday)
# Out:
# 26 3

# %%
print(t.date(),t.time())
# Out:
# 2021-06-30 20:43:51.143906

# %% [markdown]
# 借助strftime()函数可以自定义时间和日期格式，
# strftime()函数是将日期和时间的格式转化为某些自定义的格式

# %%
i = t.date()
ii = t.time()
print(i,ii)
# Out:
# 2021-06-30 20:43:51.143906

# %%
from datetime import datetime 
import locale

locale.setlocale(locale.LC_CTYPE, 'chinese')
I = i.strftime('%Y年%m月%d日 %H时：%M分：%S秒')
print(I,type(I))
# Out:
# 2021年06月30日 00时：00分：00秒 <class 'str'>

# %%
print(str(t),type(str(t)))
# Out:
# 2021-06-30 20:43:51.143906 <class 'str'>

# %%
h = datetime.strptime(I, '%Y年%m月%d日 %')
# Out:
# '2021年-06月-30日 00时：00分：00秒'

# %%
from dateutil.parser import parse

str_time = '2018-10-14'
parse(str_time)
print(type(parse(str_time)))
# Out:
# <class 'datetime.datetime'>

# %% [markdown]
# ### 时间索引
# 时间索引就是根据时间来对时间格式的字段进行数据选取的一种索引方式

# %%
import pandas as pd 
df = pd.read_excel(r'datapool/岭南师范学院第二针.xls')
df['出生日期'] = df['出生日期'].astype('datetime64[ns]')

# %%
df1 = df.sort_values(by='出生日期') 
df2 = df1.set_index(['出生日期'])
df2[:'1997-12']
# Out:
#              序号   地市   县区           接种单位   姓名 性别    工作单位      人群分类  \
# 出生日期
# 1973-12-27  154  湛江市  赤坎区  湛江中心人民医院岭师流动点  葛在波  男  岭南师范学院     教育工作者
# 1977-04-15   92  湛江市  赤坎区  湛江中心人民医院岭师流动点  朱习文  男  岭南师范学院     教育工作者
# 1994-08-25  140  湛江市  赤坎区  湛江中心人民医院岭师流动点  钟东亮  男  岭南师范学院  高等教育院校学生
# 1995-10-28  103  湛江市  赤坎区  湛江中心人民医院岭师流动点  梁雪娟  女  湛江师范学校  高等教育院校学生
# 1996-09-27   21  湛江市  赤坎区  湛江中心人民医院岭师流动点  邓笑笑  女  岭南师范学院  高等教育院校学生
# 1996-12-12  105  湛江市  赤坎区  湛江中心人民医院岭师流动点  莫志心  男  岭南师范学院  高等教育院校学生
# 1997-02-22  130  湛江市  赤坎区  湛江中心人民医院岭师流动点  唐晓丽  女  岭南师范学院  高等教育院校学生
# 1997-04-11   72  湛江市  赤坎区  湛江中心人民医院岭师流动点  陈大轩  男  岭南师范学院  高等教育院校学生
# 1997-04-26  221  湛江市  赤坎区  湛江中心人民医院岭师流动点  韦一杰  男  岭南师范学院  高等教育院校学生
# 1997-05-03    1  湛江市  赤坎区  湛江中心人民医院岭师流动点  李吉那  女  岭南师范学院  高等教育院校学生
# 25   2021-03-29    北京生物    NaN    NaN
# 35   2021-03-29    北京生物    NaN    NaN
# 38   2021-03-29    北京生物    NaN    NaN
# 56   2021-03-29    北京生物    NaN    NaN
# 58   2021-03-29    北京生物    NaN    NaN
# 60   2021-03-29    北京生物    NaN    NaN
# 76   2021-03-29    北京生物    NaN    NaN
# 82   2021-03-29    北京生物    NaN    NaN
# 86   2021-04-01  北京科兴中维    NaN    NaN
# 87   2021-04-01  北京科兴中维    NaN    NaN
# 94   2021-04-01  北京科兴中维    NaN    NaN
# 96   2021-04-01  北京科兴中维    NaN    NaN
# 98   2021-04-01  北京科兴中维    NaN    NaN
# 101  2021-04-01  北京科兴中维    NaN    NaN
# 115  2021-04-01  北京科兴中维    NaN    NaN
# 122  2021-04-01  北京科兴中维    NaN    NaN
# 126  2021-04-01  北京科兴中维    NaN    NaN
# 132  2021-04-01  北京科兴中维    NaN    NaN
# 134  2021-04-01  北京科兴中维    NaN    NaN
# 141  2021-04-01  北京科兴中维    NaN    NaN
# 143  2021-04-01  北京科兴中维    NaN    NaN
# 145  2021-04-01  北京科兴中维    NaN    NaN
# 189  2021-04-02  北京科兴中维    NaN    NaN
# 218  2021-04-02  北京科兴中维    NaN    NaN
# 223  2021-04-02  北京科兴中维    NaN    NaN
# 226  2021-04-02  北京科兴中维    NaN    NaN
# 237  2021-04-02  北京科兴中维    NaN    NaN
# 247  2021-04-02  北京科兴中维    NaN    NaN

# %% [markdown]
# ### 两个时间差
# 计算两个时间的差
# 在Python中两个时间做差返回一个timedelta对象，该对象中包含天数、秒、微妙三个等级
# 如果要获取小时、分钟，则需要进行换算

# %%
cha = datetime(2018,5,21,19,50) -datetime(2018,5,18,20,32)
cha
# Out:
# datetime.timedelta(days=2, seconds=83880)

# %%
cha.days
# Out:
# 2

# %%
cha.seconds
# Out:
# 83880

# %%
cha.seconds/3600
# Out:
# 23.3

# %% [markdown]
# ### 时间偏移
# 时间偏移是指给时间往前推或往后推一段时间，即加或减一段时间
# * 第一种是借助timedelta，但是它只能偏移天、秒、微妙单位的时间
#     > 由于timedalta只支持天、秒、微妙的时间运算，如果其他单位的时间运算，
#       则需要换算成以上三种单位中的一种方可进行偏移
# * 第二种是用Pandas中的日期偏移量（date offset）
#     > date offset可以直接实现天、小时、分钟单位的时间偏移，不需要换算，相比timedelta要方便一些

# %%
from datetime import datetime
from datetime import timedelta

date = datetime(2021,6,30,23,51,20)

print(date + timedelta(days=1))
print(date + timedelta(seconds=60))
print(date - timedelta(days=1))
print(date - timedelta(seconds=60))
# Out:
# 2021-07-01 23:51:20
# 2021-06-30 23:52:20
# 2021-06-29 23:51:20
# 2021-06-30 23:50:20

# %%
from pandas.tseries.offsets import Day,Hour,Minute
date = datetime(2018,5,18,20,32)
print(date + Day(1))
print(date + Hour(1))
print(date + Minute(10))
print(date - Day(1))
print(date - Hour(1))
print(date - Minute(10))
# Out:
# 2018-05-19 20:32:00
# 2018-05-18 21:32:00
# 2018-05-18 20:42:00
# 2018-05-17 20:32:00
# 2018-05-18 19:32:00
# 2018-05-18 20:22:00
