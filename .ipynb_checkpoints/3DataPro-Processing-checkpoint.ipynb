# %% [markdown]
# # 数据预处理

# %% [markdown]
# ## 删除含有缺失值的行

# %% [markdown]
# `df.dropna()`语句直接把含有缺失值的行全部删除
#
# `df.dropna(how='all')`传入一个参数how='all'，则只删除全为空值的行，不全为空值的行就不会被删除

# %%
import pandas as pd

df = pd.read_excel('./datapool/期末考试安排（商学院）.xlsx')
df.dropna()
# Out:
#   商学院2020-2021-2学期期末考试安排表(提前） Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                        考试时间         课程         班级         人数       考试试室
# 1            5月10日晚上7:30-9:30      宏观经济学       18酒店         34      4-301
#
#   Unnamed: 5
# 0       监考员1
# 1        王亚新

# %% [markdown]
# ## 对缺失值进行填充
#
# 在括号里面填写缺失值，会对所有的缺失空进行填充
# 也可以按不同列进行填充，只需传入一个字典**dict**,字典包含相应的键跟值，键代表填充的列，值代表填充的值

# %%
df.fillna(0)
# Out:
#   商学院2020-2021-2学期期末考试安排表(提前） Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                        考试时间         课程         班级         人数       考试试室
# 1            5月10日晚上7:30-9:30      宏观经济学       18酒店         34      4-301
# 2                           0          0       18物流         26          0
# 3                           0          0       18工商         35      4-302
#
#   Unnamed: 5
# 0       监考员1
# 1        王亚新
# 2          0
# 3         黄飞

# %%
df.fillna({'商学院2020-2021-2学期期末考试安排表(提前）':'5月10日晚上7:30-9:30'})
# Out:
#   商学院2020-2021-2学期期末考试安排表(提前） Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                        考试时间         课程         班级         人数       考试试室
# 1            5月10日晚上7:30-9:30      宏观经济学       18酒店         34      4-301
# 2            5月10日晚上7:30-9:30        NaN       18物流         26        NaN
# 3            5月10日晚上7:30-9:30        NaN       18工商         35      4-302
#
#   Unnamed: 5
# 0       监考员1
# 1        王亚新
# 2        NaN
# 3         黄飞

# %% [markdown]
# ## 重复值处理

# %% [markdown]
# 1. drop_duplicates()该方法对所有值进行重复值判断，且默认保留第一个值
# `df.drop_duplicates()`
# 2. 当只有一列重复时，也可去重复行，只需指定重复的列
# `df.drop_duplicates(subset='第一剂时间')`
# 3. 也可指定当两列去重
# `df.drop_duplicates(subset=['性别','第一剂时间'])`
#
# 可以通过指定keep参数，选择保留项
# 1. 默认值是first，即保留第一个值
# `df.drop_duplicates(keep='first')`
# 2. 也可指定为last,即保留最后一个
# `df.drop_duplicates(keep='last')`
# 3. 也可不保留任何重复值
# `df.drop_duplicates(keep=False)`

# %%
df = pd.read_excel('./datapool/岭南师范学院第二针.xls')
df.drop_duplicates(subset=['第一剂时间','性别'],keep='last')
# Out:
#       序号   地市   县区           接种单位   姓名 性别        出生日期    工作单位      人群分类  \
# 83    84  湛江市  赤坎区  湛江中心人民医院岭师流动点  胡文静  男  2002-11-03  岭南师范学院  高等教育院校学生
# 84    85  湛江市  赤坎区  湛江中心人民医院岭师流动点  徐诗怡  女  2000-08-13  岭南师范学院  高等教育院校学生
# 151  152  湛江市  赤坎区  湛江中心人民医院岭师流动点  丁雨婷  女  2001-08-05  湛江师范学校  高等教育院校学生
# 153  154  湛江市  赤坎区  湛江中心人民医院岭师流动点  葛在波  男  1973-12-27  岭南师范学院     教育工作者
# 259  260  湛江市  赤坎区  湛江中心人民医院岭师流动点  方逸夫  男  2002-08-29  岭南师范学院  高等教育院校学生
# 260  261  湛江市  赤坎区  湛江中心人民医院岭师流动点  蔡思琦  女  2001-11-18  岭南师范学院  高等教育院校学生
#
#           第一剂时间   第一剂厂家  第二剂时间  第二剂厂家
# 83   2021-03-29    北京生物    NaN    NaN
# 84   2021-03-29    北京生物    NaN    NaN
# 151  2021-04-01  北京科兴中维    NaN    NaN
# 153  2021-04-01  北京科兴中维    NaN    NaN
# 259  2021-04-02  北京科兴中维    NaN    NaN
# 260  2021-04-02  北京科兴中维    NaN    NaN

# %% [markdown]
# ## 利用dtype查看数据类型

# %%
df['第一剂时间'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ## 数据格式转换
# 数据类型：
# int:整型数
# float:浮点数
# object:Python数据类型，用O表示
# string_:字符串类型，经常用S表示
# unicode_：固定长度的unicode类型
# datetime64[ns]:表示时间格式

# %%
df['第一剂时间'] = df['第一剂时间'].astype('datetime64[ns]')

# %%
from datetime import datetime
df[df['第一剂时间'] < datetime(2021, 4, 1)]
# Out:
#     序号   地市   县区           接种单位   姓名 性别        出生日期    工作单位      人群分类  \
# 0    1  湛江市  赤坎区  湛江中心人民医院岭师流动点  李吉那  女  1997-05-03  岭南师范学院  高等教育院校学生
# 1    2  湛江市  赤坎区  湛江中心人民医院岭师流动点   曹熹  女  2001-06-07  岭南师范学院  高等教育院校学生
# 2    3  湛江市  赤坎区  湛江中心人民医院岭师流动点  苏国昊  男  1998-03-13  岭南师范学院  高等教育院校学生
# 3    4  湛江市  赤坎区  湛江中心人民医院岭师流动点  柯宝怡  女  2001-08-09  岭南师范学院  高等教育院校学生
# 4    5  湛江市  赤坎区  湛江中心人民医院岭师流动点  陈心妍  女  2002-05-28  岭南师范学院  高等教育院校学生
# ..  ..  ...  ...            ...  ... ..         ...     ...       ...
# 80  81  湛江市  赤坎区  湛江中心人民医院岭师流动点  陈立根  男  2002-08-29  岭南师范学院  高等教育院校学生
# 81  82  湛江市  赤坎区  湛江中心人民医院岭师流动点  高泳诗  女  2000-10-12  岭南师范学院  高等教育院校学生
# 82  83  湛江市  赤坎区  湛江中心人民医院岭师流动点  李翠碧  女  1998-03-15  岭南师范学院  高等教育院校学生
# 83  84  湛江市  赤坎区  湛江中心人民医院岭师流动点  胡文静  男  2002-11-03  岭南师范学院  高等教育院校学生
# 84  85  湛江市  赤坎区  湛江中心人民医院岭师流动点  徐诗怡  女  2000-08-13  岭南师范学院  高等教育院校学生
#
#         第一剂时间 第一剂厂家  第二剂时间  第二剂厂家
# 0  2021-03-29  北京生物    NaN    NaN
# 1  2021-03-29  北京生物    NaN    NaN
# 2  2021-03-29  北京生物    NaN    NaN
# 3  2021-03-29  北京生物    NaN    NaN
# 4  2021-03-29  北京生物    NaN    NaN
# ..        ...   ...    ...    ...
# 80 2021-03-29  北京生物    NaN    NaN
# 81 2021-03-29  北京生物    NaN    NaN
# 82 2021-03-29  北京生物    NaN    NaN
# 83 2021-03-29  北京生物    NaN    NaN
# 84 2021-03-29  北京生物    NaN    NaN
#
# [85 rows x 13 columns]

# %% [markdown]
# ## 可以用columns参数传入索引值
# `df.columns = [1,2,3,4,5]`

# %% [markdown]
# ## 可以用index参数传入行索引
# `df.index = [1,2,3,4,5]`

# %% [markdown]
# ## 重新设置索引值

# %%
df = pd.read_excel('./datapool/岭南师范学院第二针.xls')
df.set_index('序号').head()
# Out:
#      地市   县区           接种单位   姓名 性别        出生日期    工作单位      人群分类       第一剂时间  \
# 序号
# 1   湛江市  赤坎区  湛江中心人民医院岭师流动点  李吉那  女  1997-05-03  岭南师范学院  高等教育院校学生  2021-03-29
# 2   湛江市  赤坎区  湛江中心人民医院岭师流动点   曹熹  女  2001-06-07  岭南师范学院  高等教育院校学生  2021-03-29
# 3   湛江市  赤坎区  湛江中心人民医院岭师流动点  苏国昊  男  1998-03-13  岭南师范学院  高等教育院校学生  2021-03-29
# 4   湛江市  赤坎区  湛江中心人民医院岭师流动点  柯宝怡  女  2001-08-09  岭南师范学院  高等教育院校学生  2021-03-29
# 5   湛江市  赤坎区  湛江中心人民医院岭师流动点  陈心妍  女  2002-05-28  岭南师范学院  高等教育院校学生  2021-03-29
#
#    第一剂厂家  第二剂时间  第二剂厂家
# 序号
# 1   北京生物    NaN    NaN
# 2   北京生物    NaN    NaN
# 3   北京生物    NaN    NaN
# 4   北京生物    NaN    NaN
# 5   北京生物    NaN    NaN

# %% [markdown]
# ## 层次化索引
# 可以给set_index()传入两个或多个列命，一个表用多个列做为索引的方式叫做**层次化索引**
#
# `df = pd.read_excel(r'./datapool/期末考试安排（商学院）.xlsx',sheet_name = 1,index_col=[0,1,4],header = 1,usecols=[0,1,2,3,4])`

# %%
df = pd.read_excel(r'./datapool/期末考试安排（商学院）.xlsx',sheet_name = 1,index_col=[0,1,4],header = 1,usecols=[0,1,2,3,4])
df
# Out:
#                                                     班级  人数
# 考试时间                      课程             考试试室
# 十八周星期一（6月28日）上午8:30-10:30 大学英语II         4-302   20电商1  28
#                                          4-302   20电商2  32
#                                          4-705   20国贸1  36
#                                          4-705   20国贸2  38
#                                          4-303   20国贸3  35
#                                          4-311   20财管1  46
#                                          4-401   20财管2  40
#                                          4-312   20财管3  39
#                                          4-706   20工商1  44
#                                          4-706   20工商2  44
#                                          4-313   20工商3  43
#                                          4-804  20市场营销  48
#                                          4-804    20会计  42
# 十八周星期二（6月29日）上午8:30-10:30 旅游英语-中外名胜博览与欣赏 4-104   19级学生  61
#                                          4-105   19级学生  60
#                                          4-411   19级学生  60
#                                          4-412   19级学生  60
#                                          4-413   19级学生  60
#                           初级美国文学         4-601   19级学生  60
#                                          4-602   19级学生  60
# 十八周星期二（6月29日）下午3:00-5:00  中国近现代史纲要       4-604   20电商1  28
#                                          4-604   20电商2  32
#                                          4-503   20国贸1  36
#                                          4-601   20国贸2  38
#                                          4-502   20国贸3  35
#                                          4-412   20财管1  46
#                                          4-413   20财管2  40
#                                          4-501   20财管3  39
#                                          4-512   20工商1  44
#                                          4-513   20工商2  44
#                                          4-511   20工商3  43
#                                          4-202  20市场营销  48
#                                          4-201    20会计  42
# 十八周星期三（6月30日）上午8:30-10:30 大学语文           4-701   20电商1  28
#                                          4-705   20电商2  32
#                                          4-705    20会计  42
#                                          4-604   20国贸1  36
#                                          4-604  20市场营销  48
#                                          4-605   20国贸2  38
#                                          4-605   20国贸3  35
#                                          4-704   20财管1  46
#                                          4-704   20工商3  43
#                                          4-606   20财管2  40
#                                          4-606   20财管3  39
#                                          4-706   20工商1  44
#                                          4-706   20工商2  44
# 十八周星期三（6月30日）下午3：00-5:00  学生发展与学习心理      4-301    20会计  42

# %% [markdown]
# ## 重命名索引
# ```python
# df.rename(columns = {'接种单位':'新接种单位','性别':'sex'},index = {1:'一', 2:'二'})
# ```
# 通过rename方法，向rename里面的columns传入参数，参数为一个字典，键跟值，键为原本的列表命，值为新的列表命
# 也可以通过index参数修改列索引，方法跟columns一样

# %%
df3 = df.rename(columns = {'接种单位':'新接种单位','性别':'sex'},index = {1:'一', 2:'二'})
df3
# Out:
#       序号   地市   县区          新接种单位   姓名 sex        出生日期    工作单位      人群分类  \
# 0      1  湛江市  赤坎区  湛江中心人民医院岭师流动点  李吉那   女  1997-05-03  岭南师范学院  高等教育院校学生
# 一      2  湛江市  赤坎区  湛江中心人民医院岭师流动点   曹熹   女  2001-06-07  岭南师范学院  高等教育院校学生
# 二      3  湛江市  赤坎区  湛江中心人民医院岭师流动点  苏国昊   男  1998-03-13  岭南师范学院  高等教育院校学生
# 3      4  湛江市  赤坎区  湛江中心人民医院岭师流动点  柯宝怡   女  2001-08-09  岭南师范学院  高等教育院校学生
# 4      5  湛江市  赤坎区  湛江中心人民医院岭师流动点  陈心妍   女  2002-05-28  岭南师范学院  高等教育院校学生
# ..   ...  ...  ...            ...  ...  ..         ...     ...       ...
# 256  257  湛江市  赤坎区  湛江中心人民医院岭师流动点  巫观萍   女  2001-05-20  岭南师范学院  高等教育院校学生
# 257  258  湛江市  赤坎区  湛江中心人民医院岭师流动点  潘昌龙   男  2000-10-06  岭南师范学院  高等教育院校学生
# 258  259  湛江市  赤坎区  湛江中心人民医院岭师流动点  赖家南   男  2000-03-13  岭南师范学院  高等教育院校学生
# 259  260  湛江市  赤坎区  湛江中心人民医院岭师流动点  方逸夫   男  2002-08-29  岭南师范学院  高等教育院校学生
# 260  261  湛江市  赤坎区  湛江中心人民医院岭师流动点  蔡思琦   女  2001-11-18  岭南师范学院  高等教育院校学生
#
#           第一剂时间   第一剂厂家  第二剂时间  第二剂厂家
# 0    2021-03-29    北京生物    NaN    NaN
# 一    2021-03-29    北京生物    NaN    NaN
# 二    2021-03-29    北京生物    NaN    NaN
# 3    2021-03-29    北京生物    NaN    NaN
# 4    2021-03-29    北京生物    NaN    NaN
# ..          ...     ...    ...    ...
# 256  2021-04-02  北京科兴中维    NaN    NaN
# 257  2021-04-02  北京科兴中维    NaN    NaN
# 258  2021-04-02  北京科兴中维    NaN    NaN
# 259  2021-04-02  北京科兴中维    NaN    NaN
# 260  2021-04-02  北京科兴中维    NaN    NaN
#
# [261 rows x 13 columns]

# %% [markdown]
# ## 重置索引
# 重置索引主要引用在层次化索引表中，重置索引是将索引列当作一个columns进行返回
# level参数用来指定要层次化索引的第几级传化为columns,第一个索引为0级，第二个索引为1级，默认为全部索引，即默认索引全部转化为columns
# drop参数用来指定是否将原索引删掉，即不作为一个新的columns，默认为False,即不删除原索引
# inplace参数用来指定是否修改原数据表
# `reset_index(level=None,drop=False,inplace=False)`
# reset_index()方法常用于数据分组、数据透视表中

# %%
df = pd.read_excel(r'datapool/期末考试安排（商学院）.xlsx',sheet_name = 1,index_col=[0,1,4],header = 1,usecols=[0,1,2,3,4])
df1 = df.reset_index()
df1['考试时间']
# Out:
# 0     十八周星期一（6月28日）上午8:30-10:30
# 1     十八周星期一（6月28日）上午8:30-10:30
# 2     十八周星期一（6月28日）上午8:30-10:30
# 3     十八周星期一（6月28日）上午8:30-10:30
# 4     十八周星期一（6月28日）上午8:30-10:30
# 5     十八周星期一（6月28日）上午8:30-10:30
# 6     十八周星期一（6月28日）上午8:30-10:30
# 7     十八周星期一（6月28日）上午8:30-10:30
# 8     十八周星期一（6月28日）上午8:30-10:30
# 9     十八周星期一（6月28日）上午8:30-10:30
# 10    十八周星期一（6月28日）上午8:30-10:30
# 11    十八周星期一（6月28日）上午8:30-10:30
# 12    十八周星期一（6月28日）上午8:30-10:30
# 13    十八周星期二（6月29日）上午8:30-10:30
# 14    十八周星期二（6月29日）上午8:30-10:30
# 15    十八周星期二（6月29日）上午8:30-10:30
# 16    十八周星期二（6月29日）上午8:30-10:30
# 17    十八周星期二（6月29日）上午8:30-10:30
# 18    十八周星期二（6月29日）上午8:30-10:30
# 19    十八周星期二（6月29日）上午8:30-10:30
# 20     十八周星期二（6月29日）下午3:00-5:00
# 21     十八周星期二（6月29日）下午3:00-5:00
# 22     十八周星期二（6月29日）下午3:00-5:00
# 23     十八周星期二（6月29日）下午3:00-5:00
# 24     十八周星期二（6月29日）下午3:00-5:00
# 25     十八周星期二（6月29日）下午3:00-5:00
# 26     十八周星期二（6月29日）下午3:00-5:00
# 27     十八周星期二（6月29日）下午3:00-5:00
# 28     十八周星期二（6月29日）下午3:00-5:00
# 29     十八周星期二（6月29日）下午3:00-5:00
# 30     十八周星期二（6月29日）下午3:00-5:00
# 31     十八周星期二（6月29日）下午3:00-5:00
# 32     十八周星期二（6月29日）下午3:00-5:00
# 33    十八周星期三（6月30日）上午8:30-10:30
# 34    十八周星期三（6月30日）上午8:30-10:30
# 35    十八周星期三（6月30日）上午8:30-10:30
# 36    十八周星期三（6月30日）上午8:30-10:30
# 37    十八周星期三（6月30日）上午8:30-10:30
# 38    十八周星期三（6月30日）上午8:30-10:30
# 39    十八周星期三（6月30日）上午8:30-10:30
# 40    十八周星期三（6月30日）上午8:30-10:30
# 41    十八周星期三（6月30日）上午8:30-10:30
# 42    十八周星期三（6月30日）上午8:30-10:30
# 43    十八周星期三（6月30日）上午8:30-10:30
# 44    十八周星期三（6月30日）上午8:30-10:30
# 45    十八周星期三（6月30日）上午8:30-10:30
# 46     十八周星期三（6月30日）下午3：00-5:00
# Name: 考试时间, dtype: object
